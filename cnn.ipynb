# %% [markdown]
# <a href="https://colab.research.google.com/github/mxykb/413CW1/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-*-coding:utf-8-*-
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import keras
import pywt
import math
import numpy as np
import pandas as pd
from keras.models import Sequential
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from keras import optimizers
from keras.layers import Dense, Dropout
import itertools
from keras.layers import Activation
from keras.callbacks import TensorBoard

def score(y_test,predictions):
    accuracy = metrics.accuracy_score(y_test, predictions)
    recall = metrics.recall_score(y_test, predictions, average="weighted")
    precision = metrics.precision_score(y_test, predictions, average="weighted")
    F1 = metrics.f1_score(y_test, predictions, average="weighted")  
    print("accuracy:",  accuracy, '\n', "precision:", precision, '\n', "recall:", recall, '\n', "F1 :",  F1)
    return accuracy,precision,recall,F1

def plot_confusion_matrix(cm, classes, title="Confusion Matrix", cmap=plt.cm.Blues):
    """
    The function prints and plots the confusion matrix
    """
    plt.imshow(cm, interpolation="nearest", cmap=cmap)#set colour map from deep to light
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes)) #The lables of the cluster
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment='center',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    
dataframe = pd.read_csv('http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv', header=None)
raw_data = dataframe.values
dataframe.head()
# The last element contains the labels
labels = raw_data[:, -1]

# The other data points are the electrocadriogram data
ecg = raw_data[:, 0:-1]

def denoise(ecg):
    index=[]
    data=[]
    coffs=[]
    
    for i in range(len(ecg)-1):
        X=float(i)
        Y=float(ecg[i])
        index.append(X)
        data.append(Y)
    #create wavelet object and define parameters
    w=pywt.Wavelet('db8')#choose Daubechies8 wavelet
    maxlev=pywt.dwt_max_level(len(data),w.dec_len)
    
    threshold=0  #Threshold for filtering
    
    #Decompose into wavelet components,to the level selected:
    coffs=pywt.wavedec(data,'db8',level=maxlev) #Wavelet decomposition of signals
    
    for i in range(1,len(coffs)):
        coffs[i]=pywt.threshold(coffs[i],threshold*max(coffs[i]))
    
    datarec=pywt.waverec(coffs,'db8')#Wavelet reconstruction of signals
    return np.array(datarec)

denoiseData=np.array([])

min_val = tf.reduce_min(ecg)
max_val = tf.reduce_max(ecg)
ecg = (ecg - min_val) / (max_val - min_val)

for ecgdata in ecg:
    if(len(denoiseData) == 0):
        denoiseData = denoise(ecgdata)
    else:
        denoiseData = np.vstack((denoiseData,denoise(ecgdata)))

train_data, test_data, train_labels, test_labels = train_test_split(denoiseData, labels, test_size=0.2, random_state=21)


X = train_data
y = train_labels

digits = 2
examples = y.shape[0]
y = y.reshape(1, examples)
Y = np.eye(digits)[y.astype('int32')]
Y = Y.T.reshape(digits, examples).T


X2 = test_data
y2 = test_labels

examples = y2.shape[0]
y2 = y2.reshape(1, examples)
Y2 = np.eye(digits)[y2.astype('int32')]
Y2 = Y2.T.reshape(digits, examples).T

inputECG = keras.Input(batch_shape=(None,140,1))
x = keras.layers.Conv1D(64,3, activation='relu', padding='valid')(inputECG)
x1 = keras.layers.MaxPooling1D(2)(x)
x2 = keras.layers.Conv1D(32,3, activation='relu', padding='valid')(x1)
x3 = keras.layers.MaxPooling1D(2)(x2)
flat = keras.layers.Flatten()(x3)
encoded = Dense(32,activation = 'relu')(flat)
     
model_encoder = keras.Model(inputECG,encoded)
     
    # DECODER 
x2_ = keras.layers.Conv1D(32, 3, activation='relu', padding='valid')(x3)
x1_ = keras.layers.UpSampling1D(2)(x2_)
x_ = keras.layers.Conv1D(64, 3, activation='relu', padding='valid')(x1_)
upsamp = keras.layers.UpSampling1D(2)(x_)
flat = keras.layers.Flatten()(upsamp)
decoded = Dense(140,activation = 'relu')(flat)
decoded = keras.layers.Reshape((140,1))(decoded)

X = X[...,None]
X2 = X2[...,None]


model = keras.Sequential()
model.add(model_encoder.layers[0])
model.add(model_encoder.layers[1])
model.add(model_encoder.layers[2])
model.add(model_encoder.layers[3])
model.add(model_encoder.layers[4])
model.add(model_encoder.layers[5])
model.add(model_encoder.layers[6])
#
model.add(keras.layers.Dense(2, activation='softmax'))
#
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

hist = model.fit(X, Y, epochs=100, batch_size=32)

plt.plot(hist.history["loss"]);
plt.xlabel('Epochs');
plt.ylabel('Training Error');
plt.show()

predict = model.predict(X2)
predict = np.argmax(predict, axis=1)
Y= np.argmax(Y, axis=1)
Y2= np.argmax(Y2, axis=1)
cnf_matrix = confusion_matrix(Y2, predict)#create confusion matrix
accuracy1,precision1,recall1,f1 = score(Y2,predict)#calculate the score of the model
class_names=[0,1]
plt.figure#plot the confusion matrix
plot_confusion_matrix(cnf_matrix,classes=class_names, title="Confusion matrix")
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# ...
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# maximum level is3
# Epoch 1/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1694 - accuracy: 0.9201
# Epoch 2/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0431 - accuracy: 0.9891
# Epoch 3/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0259 - accuracy: 0.9934
# Epoch 4/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0200 - accuracy: 0.9936
# Epoch 5/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0255 - accuracy: 0.9928
# Epoch 6/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0163 - accuracy: 0.9957
# Epoch 7/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0214 - accuracy: 0.9949
# Epoch 8/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0131 - accuracy: 0.9960
# Epoch 9/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0150 - accuracy: 0.9959
# Epoch 10/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 11/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0113 - accuracy: 0.9981
# Epoch 12/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0138 - accuracy: 0.9967
# Epoch 13/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0100 - accuracy: 0.9980
# Epoch 14/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0088 - accuracy: 0.9969
# Epoch 15/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0113 - accuracy: 0.9972
# Epoch 16/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 17/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 18/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0106 - accuracy: 0.9961
# Epoch 19/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 20/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0063 - accuracy: 0.9978
# Epoch 21/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0100 - accuracy: 0.9975
# Epoch 22/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0083 - accuracy: 0.9989
# Epoch 23/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0051 - accuracy: 0.9993
# Epoch 24/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0037 - accuracy: 0.9991
# Epoch 25/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0066 - accuracy: 0.9978
# Epoch 26/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0041 - accuracy: 0.9990
# Epoch 27/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0021 - accuracy: 0.9996
# Epoch 28/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 29/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 30/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 31/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 32/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 33/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 34/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 35/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 36/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 37/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 38/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 39/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 40/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0019 - accuracy: 0.9998
# Epoch 41/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 42/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 43/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0010 - accuracy: 0.9995
# Epoch 44/100
# 125/125 [==============================] - 2s 14ms/step - loss: 7.9521e-04 - accuracy: 0.9998
# Epoch 45/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 46/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 47/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 48/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0011 - accuracy: 0.9993
# Epoch 49/100
# 125/125 [==============================] - 2s 14ms/step - loss: 9.6447e-04 - accuracy: 0.9994
# Epoch 50/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 51/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 52/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.7026e-04 - accuracy: 1.0000
# Epoch 53/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.5043e-04 - accuracy: 0.9996
# Epoch 54/100
# 125/125 [==============================] - 2s 14ms/step - loss: 9.9511e-04 - accuracy: 0.9996
# Epoch 55/100
# 125/125 [==============================] - 2s 14ms/step - loss: 7.8554e-04 - accuracy: 0.9998
# Epoch 56/100
# 125/125 [==============================] - 2s 14ms/step - loss: 3.3181e-04 - accuracy: 0.9997
# Epoch 57/100
# 125/125 [==============================] - 2s 14ms/step - loss: 4.8055e-04 - accuracy: 0.9999
# Epoch 58/100
# 125/125 [==============================] - 2s 14ms/step - loss: 5.8848e-04 - accuracy: 0.9998
# Epoch 59/100
# 125/125 [==============================] - 2s 14ms/step - loss: 7.0314e-05 - accuracy: 1.0000
# Epoch 60/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.4316e-05 - accuracy: 1.0000
# Epoch 61/100
# 125/125 [==============================] - 2s 14ms/step - loss: 2.0994e-04 - accuracy: 0.9999
# Epoch 62/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0015 - accuracy: 0.9997
# Epoch 63/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.2684e-05 - accuracy: 1.0000
# Epoch 64/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.4992e-04 - accuracy: 0.9996
# Epoch 65/100
# 125/125 [==============================] - 2s 14ms/step - loss: 9.9697e-05 - accuracy: 1.0000
# Epoch 66/100
# 125/125 [==============================] - 2s 14ms/step - loss: 2.7833e-04 - accuracy: 0.9998
# Epoch 67/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.5375e-05 - accuracy: 1.0000
# Epoch 68/100
# 125/125 [==============================] - 2s 14ms/step - loss: 2.4403e-04 - accuracy: 1.0000
# Epoch 69/100
# 125/125 [==============================] - 2s 14ms/step - loss: 3.1530e-04 - accuracy: 1.0000
# Epoch 70/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0037 - accuracy: 0.9997
# Epoch 71/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.3911e-05 - accuracy: 1.0000
# Epoch 72/100
# 125/125 [==============================] - 2s 14ms/step - loss: 5.0048e-05 - accuracy: 1.0000
# Epoch 73/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.6173e-04 - accuracy: 0.9999
# Epoch 74/100
# 125/125 [==============================] - 2s 14ms/step - loss: 3.4736e-05 - accuracy: 1.0000
# Epoch 75/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.7189e-05 - accuracy: 1.0000
# Epoch 76/100
# 125/125 [==============================] - 2s 14ms/step - loss: 4.0310e-06 - accuracy: 1.0000
# Epoch 77/100
# 125/125 [==============================] - 2s 14ms/step - loss: 4.8182e-04 - accuracy: 0.9998
# Epoch 78/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.3331e-05 - accuracy: 1.0000
# Epoch 79/100
# 125/125 [==============================] - 2s 14ms/step - loss: 3.0199e-05 - accuracy: 1.0000
# Epoch 80/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.5840e-04 - accuracy: 0.9999
# Epoch 81/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.6246e-06 - accuracy: 1.0000
# Epoch 82/100
# 125/125 [==============================] - 2s 14ms/step - loss: 2.0016e-04 - accuracy: 1.0000
# Epoch 83/100
# 125/125 [==============================] - 2s 14ms/step - loss: 3.4334e-05 - accuracy: 1.0000
# Epoch 84/100
# 125/125 [==============================] - 2s 14ms/step - loss: 2.1316e-05 - accuracy: 1.0000
# Epoch 85/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.3249e-05 - accuracy: 1.0000
# Epoch 86/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.3825e-04 - accuracy: 0.9998
# Epoch 87/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.0512e-05 - accuracy: 1.0000
# Epoch 88/100
# 125/125 [==============================] - 2s 14ms/step - loss: 5.2367e-04 - accuracy: 0.9995
# Epoch 89/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.5311e-05 - accuracy: 1.0000
# Epoch 90/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.1145e-07 - accuracy: 1.0000
# Epoch 91/100
# 125/125 [==============================] - 2s 14ms/step - loss: 7.5793e-07 - accuracy: 1.0000
# Epoch 92/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0010 - accuracy: 0.9995
# Epoch 93/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.7628e-05 - accuracy: 0.9999
# Epoch 94/100
# 125/125 [==============================] - 2s 14ms/step - loss: 1.2737e-04 - accuracy: 1.0000
# Epoch 95/100
# 125/125 [==============================] - 2s 14ms/step - loss: 8.7484e-07 - accuracy: 1.0000
# Epoch 96/100
# 125/125 [==============================] - 2s 14ms/step - loss: 4.1170e-07 - accuracy: 1.0000
# Epoch 97/100
# 125/125 [==============================] - 2s 14ms/step - loss: 5.7825e-07 - accuracy: 1.0000
# Epoch 98/100
# 125/125 [==============================] - 2s 14ms/step - loss: 7.6027e-07 - accuracy: 1.0000
# Epoch 99/100
# 125/125 [==============================] - 2s 14ms/step - loss: 5.4352e-06 - accuracy: 1.0000
# Epoch 100/100
# 125/125 [==============================] - 2s 14ms/step - loss: 6.9250e-06 - accuracy: 1.0000
# accuracy: 0.992
#  precision: 0.992112676056338
#  recall: 0.992
#  F1 : 0.9919916715466197
